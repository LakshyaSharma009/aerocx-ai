# %%
import numpy as np

# %%
arr = np.array([3,2,5,33,5,2])

# %%
np.mean(arr)
# Out:
# 10.75

# %%
print(np.min(arr))
np.max(arr)
# Out:
# 2
# 33

# %%
np.std(arr)
# Out:
# 12.891373084353738

# %%
np.percentile(arr,50)
# Out:
# 4.0

# %%
np.argmin(arr)
# Out:
# 1

# %%
np.unique(arr)
# Out:
# array([ 2,  3,  5, 33])

# %%
t= np.cumsum(arr)

# %%
type(t)
# Out:
# numpy.ndarray

# %%
t
# Out:
# array([ 3,  5, 10, 43, 48, 50])
