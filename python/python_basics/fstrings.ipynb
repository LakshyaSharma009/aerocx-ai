# %%
name = "joe"
age = 45
print(f"my name is {name} and my age is {age}")
# Out:
# my name is joe and my age is 45

# %%
print(f"{"python":<10}")
# Out:
# python

# %%
print(f"{"python":>10}")
# Out:
#     python
