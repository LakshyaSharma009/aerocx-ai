# %%
a=10
b=5

# %%
a+b
# Out:
# 15

# %%
a-b
# Out:
# 5

# %%
a*b
# Out:
# 50

# %%
a/b
# Out:
# 2.0

# %%
a//b
# Out:
# 2

# %%
a%b
# Out:
# 0

# %%
a**b
# Out:
# 100000

# %%
a>=b
# Out:
# True

# %%
a>b
# Out:
# True

# %%
b>a
# Out:
# False

# %%
a and b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a and b
#
# NameError: name 'a' is not defined

# %%
a=True
b=False

# %%
a and b
# Out:
# False

# %%
not(b)
# Out:
# True

# %%
5 & 3
# Out:
# 1
