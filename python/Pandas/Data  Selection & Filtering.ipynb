# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.loc[8,"Film"]
# Out:
# 'Good Newwz'

# %%
df.loc[0:2,["Actor","BoxOffice(INR Crore)"]]
# Out:
#             Actor  BoxOffice(INR Crore)
# 0  Shah Rukh Khan                  1050
# 1     Salman Khan                   565
# 2      Aamir Khan                  2024

# %%
df.at[0,"Actor"]
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[2,1]
# Out:
# 'Dangal'

# %%
df[df["IMDb"]>6]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
df[(df['IMDb']>6) & (df['Year']>2019)]
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
df.query("Year>2018 and IMDb>7")
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 11                   342   8.2

# %%
df2 = df[["Actor","IMDb"]]

# %%
df2
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df2.loc[0,"Actor"]="Lakshya"

# %%
df2
# Out:
#                  Actor  IMDb
# 0              Lakshya   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df2.query("Actor == 'Lakshya'")
# Out:
#      Actor  IMDb
# 0  Lakshya   7.2
