# %%
import pandas as pd

# %%
s1=pd.Series([71,84,56,23,56,98,56])

# %%
s1
# Out:
# 0    71
# 1    84
# 2    56
# 3    23
# 4    56
# 5    98
# 6    56
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s2=pd.Series([71,84,56,23,56,98,56],index=["harry","shubh","rohan","akash","kirti","john","rehan"])

# %%
s2
# Out:
# harry    71
# shubh    84
# rohan    56
# akash    23
# kirti    56
# john     98
# rehan    56
# dtype: int64

# %%
s2["harry"]
# Out:
# 71

# %%
data={"name":["alice","bob","charlie"],"age":[25,30,35],"city":["delhi","mumbai","bangalore"]}

# %%
df=pd.DataFrame(data)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
type(data)
# Out:
# dict

# %%
df
# Out:
#       name  age       city
# 0    alice   25      delhi
# 1      bob   30     mumbai
# 2  charlie   35  bangalore
