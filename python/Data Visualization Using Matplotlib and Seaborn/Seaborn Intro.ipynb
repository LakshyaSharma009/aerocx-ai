# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set_theme(style="dark")

# %%
x = np.random.randint(101,size=10)
y=np.sin(x)

# %%
y
x
# Out:
# array([83, 73, 71, 74,  3, 52, 97, 26, 61, 10])

# %%
sns.lineplot(x=x,y=y)
# Out:
# <Axes: >
