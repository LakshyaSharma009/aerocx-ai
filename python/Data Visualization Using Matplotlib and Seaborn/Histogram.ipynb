# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
data = np.random.randint(0,101,size=50)

# %%
type(data)
# Out:
# numpy.ndarray

# %%
plt.hist(data,bins=5,edgecolor='black')
plt.xlabel("marks")
plt.ylabel("no of students")
# Out:
# Text(0, 0.5, 'no of students')

# %%
ages=[np.random.randint(1,101,size=100)]
ages
# Out:
# [array([  9,  25,  76,  88,  73,  36,  54,  38,  90,  67,  66,   7,  70,
#          32,  20,  40, 100,   9,  19,  19,  65,  73,  77,  94,  24,  37,
#          68,  79,  48,  93,  55,  82,  46,   9,  64,  54,  55,  66,  70,
#          13,  97,  55,  55,  59,  55,   5,  43,  96,  13,  61,  40,  64,
#          43,  37,  84,  14,   9,  10,  93,  46,  68,  31,  31,  18,  49,
#          24,  59,  26,  75,  80,   3,  23,  97,  88,  13,  39,  49,  62,
#          52,   9,  38,   4,  70,  38,  24,  69,  72,  61,  68,  33,  63,
#          97,  82,  39,  40,  89,  24,   8,  55,  27])]

# %%
bins=[10,20,30,40,50,60,70]
plt.hist(ages,bins=bins,edgecolor='black')
plt.title('Age Distribution of YouTube Viewers')
plt.xlabel('Age Group')
plt.ylabel('Number of Viewers')
plt.grid(True,linestyle='--',alpha=1)

# %%
plt.hist(ages,bins=bins,edgecolor='black')
plt.axvline(np.mean(ages),linestyle="--",linewidth=3,color='red')
plt.title('Age Distribution of YouTube Viewers')
plt.xlabel('Age Group')
plt.ylabel('Number of Viewers')
plt.grid(True,linestyle='--',alpha=0.5)
